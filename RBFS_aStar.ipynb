# %%
class Queue:

    def __init__(self, pop_index=0):
        self.queue = []
        self.pop_index = pop_index

    def append(self, item):
        self.queue.append(item)

    def sortAppend(self, item, f):
        self.queue.append(item)
        self.queue.sort(key=f)

    def extend(self, items):
        self.queue.extend(items)

    def pop(self):
        if len(self.queue) > 0:
            return self.queue.pop(self.pop_index)
        else:
            raise Exception('FIFOQueue is empty')

    def printQueue(self):
        print("Frontier Status After Adding .............")
        print([items.state for items in self.queue])

    def __len__(self):
        return len(self.queue)

    def __contains__(self, item):
        return item in self.queue


graph = {
    'Arad': {'Sibiu': 140, 'Timisoara': 118, 'Zerind': 75},
    'Bucharest': {'Guirgiu': 90, 'Pitesti': 101, 'Urziceni': 85},
    'Craiova': {'Drobeta': 120, 'Pitesti': 138, 'Rimnicu Vilcea': 146},
    'Drobeta': {'Craiova': 120, 'Mehadia': 75},
    'Eforie': {'Hirsova': 86},
    'Iasi': {'Neamt': 87, 'Vaslui': 92},
    'Lugoj': {'Mehadia': 70, 'Timisoara': 111},
    'Mehadia': {'Droeta': 75, 'Lugoj': 70},
    'Neamt': {'Iasi': 87},
    'Oradea': {'Sibiu': 151, 'Zerind': 70},
    'Pitesti': {'Bucharest': 101, 'Craiova': 138, 'Rimnicu Vilcea': 97},
    'Rimnicu Vilcea': {'Craiova': 146, 'Pitesti': 97, 'Sibiu': 80},
    'Sibiu': {'Arad': 140, 'Oradia': 151},
    'Timisoara': {'Arad': 118, 'Lugoj': 111},
    'Urziceni': {'Bucharest': 85, 'Hirsova': 98, 'Vaslui': 142},
    'Vaslui': {'Iasi': 92, 'Urziceni': 142},
    'Zerind': {'Arad': 75, 'Oradea': 71}
}


class graphProblem:

    def __init__(self, initial, goal, graph):
        self.initial = initial
        self.goal = goal
        self.graph = graph

    def actions(self, state):
        return list(self.graph[state].keys())

    def result(self, state, action):
        return action

    def goal_test(self, state):
        return state == self.goal

    def path_cost(self, cost_so_far, state1, action, state2):
        return cost_so_far + self.graph[state1][state2]


class Node:
    def __init__(self, state, parent=None, action=None, path_cost=0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def expand(self, graphProblem):
        return [self.child_node(graphProblem, action)
                for action in graphProblem.actions(self.state)]

    def child_node(self, graphProblem, action):
        next_state = graphProblem.result(self.state, action)
        return Node(next_state, self, action,
                    graphProblem.path_cost(self.path_cost, self.state, action, next_state))

    def path(self):
        node, path_back = self, []

        while node:
            path_back.append(node)
            node = node.parent

        return list(reversed(path_back))

    def solution(self):
        return [node.action for node in self.path()[1:]]


def graph_search(problem, pop_index):
    node = Node(problem.initial)

    if problem.goal_test(node.state): return node

    frontier = Queue(pop_index)

    explored = set()

    frontier.append(node)

    while frontier:

        frontier.printQueue()
        node = frontier.pop()

        print("Parent: ", node.state,
              "Childs: ", [child.state for child in node.expand(problem)])

        explored.add(node.state)

        for child in node.expand(problem):
            if problem.goal_test(child.state): return child
            if child.state not in explored and child not in frontier: frontier.append(child)

    return None


gp = graphProblem("Arad", "Bucharest", graph)

heuristicSLD = {
    'Arad': 366,
    'Bucharest': 0,
    'Craiova': 160,
    'Drobeta': 242,
    'Eforie': 161,
    'Fagaras': 176,
    'Giurgiu': 77,
    'Hirsova': 151,
    'Iasi': 226,
    'Lugoj': 244,
    'Mehadia': 241,
    'Neamt': 234,
    'Oradea': 380,
    'Pitesti': 100,
    'Rimnicu Vilcea': 193,
    'Sibiu': 253,
    'Timisoara': 329,
    'Urziceni': 80,
    'Vaslui': 199,
    'Zerind': 374
}


def best_first_search(problem, f, pop_index=0):
    node = Node(problem.initial)
    if problem.goal_test(node.state): return node

    frontier = Queue(pop_index)
    frontier.sortAppend(node, f)

    explored = Queue()

    while frontier:

        frontier.printQueue()
        node = frontier.pop()

        # print("Parent: ",node.state,
        #      "Childs: ",[child.state for child in node.expand(problem)])

        if problem.goal_test(node.state): return node
        explored.append(node)

        for child in node.expand(problem):
            if child not in explored and child not in frontier:
                frontier.sortAppend(child, f)

    return None


def uniform_cost_search(problem):
    return best_first_search(problem, lambda node: node.path_cost)


def GBFS(problem):
    return best_first_search(problem, lambda node: heuristicSLD[node.state])


def aStar_search(problem):
    return best_first_search(problem, lambda node: node.path_cost + heuristicSLD[node.state])


print("=======================================")
print()
print("----------GBFS State Space-------------")

goalNode = GBFS(gp)
print("Result:", goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
print("=======================================")
print()

print("----------A* State Space-------------")

goalNode = aStar_search(gp)
print("Result:", goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
# Out:
# =======================================
#
# ----------GBFS State Space-------------
# Frontier Status After Adding .............
# ['Arad']
# Frontier Status After Adding .............
# ['Sibiu', 'Timisoara', 'Zerind']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-6eeb8d179f73> in <module>
#     199 print("----------GBFS State Space-------------")
#     200
# --> 201 goalNode = GBFS(gp)
#     202 print("Result:", goalNode.solution())
#     203 print("Path Cost: ", goalNode.path_cost)
#
# <ipython-input-1-6eeb8d179f73> in GBFS(problem)
#     188
#     189 def GBFS(problem):
# --> 190     return best_first_search(problem, lambda node: heuristicSLD[node.state])
#     191
#     192
#
# <ipython-input-1-6eeb8d179f73> in best_first_search(problem, f, pop_index)
#     178         for child in node.expand(problem):
#     179             if child not in explored and child not in frontier:
# --> 180                 frontier.sortAppend(child, f)
#     181
#     182     return None
#
# <ipython-input-1-6eeb8d179f73> in sortAppend(self, item, f)
#      10     def sortAppend(self, item, f):
#      11         self.queue.append(item)
# ---> 12         self.queue.sort(key=f)
#      13
#      14     def extend(self, items):
#
# <ipython-input-1-6eeb8d179f73> in <lambda>(node)
#     188
#     189 def GBFS(problem):
# --> 190     return best_first_search(problem, lambda node: heuristicSLD[node.state])
#     191
#     192
#
# KeyError: 'Oradia'

# %%
class Queue:

 

    def __init__(self,pop_index=0):
        self.queue = []
        self.pop_index=pop_index

 

    def append(self, item):
        self.queue.append(item)

 

    def sortAppend(self, item,f):
        self.queue.append(item)
        self.queue.sort(key=f)    

 

    def extend(self, items):
        self.queue.extend(items)     

 

    def pop(self):
        if len(self.queue) > 0:
            return self.queue.pop(self.pop_index)
        else:
            raise Exception('FIFOQueue is empty')

 

    def printQueue(self):
        print("Frontier Status After Adding .............")
        print([items.state for items in self.queue])

 

    def __len__(self):
        return len(self.queue)

 

    def __contains__(self, item):        
        return item in self.queue

 


graph={
    'S':{'A':2,'B':1,'G':9},
    'A':{'C':2,'D':3},
    'B':{'D':2,'E':4},
    'C':{'G':4},
    'D':{'G':4},
    'E':{},
    'G':{}
    }

 

 

class graphProblem:

 

    def __init__(self,initial,goal,graph):
        self.initial=initial
        self.goal=goal
        self.graph=graph

 

    def actions(self,state):
        return list(self.graph[state].keys())

 

    def result(self,state,action):
        return action

 

    def goal_test(self,state):
        return state == self.goal

 

    def path_cost(self,cost_so_far,state1,action,state2):
        return cost_so_far + self.graph[state1][state2]

 


class Node:
    def __init__(self,state,parent=None,action=None,path_cost=0):
        self.state=state
        self.parent=parent
        self.action=action
        self.path_cost=path_cost

 

    def expand(self,graphProblem):
        return [self.child_node(graphProblem,action)
                for action in graphProblem.actions(self.state)]
        

 

    def child_node(self,graphProblem,action):
        next_state=graphProblem.result(self.state,action)        
        return Node(next_state,self,action,
                    graphProblem.path_cost(self.path_cost,self.state,action,next_state))

 

    def path(self):        
        node, path_back = self, []       
        
        while node:            
            path_back.append(node)            
            node = node.parent
            
        
        return list(reversed(path_back))

 

    def solution(self):        
        return [node.action for node in self.path()[1:]]
    

 

def graph_search(problem,pop_index):    

 

    node=Node(problem.initial)
    
    if problem.goal_test(node.state): return node

 

    frontier = Queue(pop_index)
    
    explored = set()

 

    frontier.append(node)

 

    while frontier:

 

        frontier.printQueue()
        node = frontier.pop()

 

        print("Parent: ",node.state,
              "Childs: ",[child.state for child in node.expand(problem)])

 

        explored.add(node.state)

 

        for child in node.expand(problem):
            if problem.goal_test(child.state): return child
            if child.state not in explored and child not in frontier: frontier.append(child)

 

    return None

 

 

gp=graphProblem("S","G",graph)

 


heuristicSLD={
    'S':6,
    'A':0,
    'B':6,
    'C':4,
    'D':1,
    'E':10,
    'G':0  
    }

 


def best_first_search(problem,f,pop_index=0):
    
    node = Node(problem.initial)
    if problem.goal_test(node.state): return node
    
    frontier = Queue(pop_index)
    frontier.sortAppend(node,f)
    
    explored = Queue()
    
    while frontier:

 

        frontier.printQueue()
        node = frontier.pop()

 

        #print("Parent: ",node.state,
        #      "Childs: ",[child.state for child in node.expand(problem)])
        
        if problem.goal_test(node.state): return node
        explored.append(node)

 

        for child in node.expand(problem):
            if child not in explored and child not in frontier:
                frontier.sortAppend(child,f)

 

    return None

 


def uniform_cost_search(problem):
    return best_first_search(problem,lambda node:node.path_cost)

 


def GBFS(problem):
    return best_first_search(problem,lambda node:heuristicSLD[node.state])

 

def aStar_search(problem):
    return best_first_search(problem,lambda node:node.path_cost+heuristicSLD[node.state])
    

 

 

print("=======================================")
print()
print("----------GBFS State Space-------------")
      
goalNode=GBFS(gp)
print("Result:",goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
print("=======================================")
print()

 

 

print("----------A* State Space-------------")
      
goalNode=aStar_search(gp)
print("Result:",goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
# Out:
# =======================================
#
# ----------GBFS State Space-------------
# Frontier Status After Adding .............
# ['S']
# Frontier Status After Adding .............
# ['A', 'G', 'B']
# Frontier Status After Adding .............
# ['G', 'D', 'C', 'B']
# Result: ['G']
# Path Cost:  9
# =======================================
#
# ----------A* State Space-------------
# Frontier Status After Adding .............
# ['S']
# Frontier Status After Adding .............
# ['A', 'B', 'G']
# Frontier Status After Adding .............
# ['D', 'B', 'C', 'G']
# Frontier Status After Adding .............
# ['B', 'C', 'G', 'G']
# Frontier Status After Adding .............
# ['D', 'C', 'G', 'G', 'E']
# Frontier Status After Adding .............
# ['G', 'C', 'G', 'G', 'E']
# Result: ['B', 'D', 'G']
# Path Cost:  7

# %%
class Queue:

    def __init__(self, pop_index=0):
        self.queue = []
        self.pop_index = pop_index

    def append(self, item):
        self.queue.append(item)

    def sortAppend(self, item, f):
        self.queue.append(item)
        self.queue.sort(key=f)

    def extend(self, items):
        self.queue.extend(items)

    def pop(self):
        if len(self.queue) > 0:
            return self.queue.pop(self.pop_index)
        else:
            raise Exception('FIFOQueue is empty')

    def printQueue(self):
        print("Frontier Status After Adding .............")
        print([items.state for items in self.queue])

    def __len__(self):
        return len(self.queue)

    def __contains__(self, item):
        return item in self.queue


graph = {
    'Arad': {'Sibiu': 140, 'Timisoara': 118, 'Zerind': 75},
    'Bucharest': {'Guirgiu': 90, 'Pitesti': 101, 'Urziceni': 85},
    'Craiova': {'Drobeta': 120, 'Pitesti': 138, 'Rimnicu Vilcea': 146},
    'Drobeta': {'Craiova': 120, 'Mehadia': 75},
    'Eforie': {'Hirsova': 86},
    'Iasi': {'Neamt': 87, 'Vaslui': 92},
    'Lugoj': {'Mehadia': 70, 'Timisoara': 111},
    'Mehadia': {'Drobeta': 75, 'Lugoj': 70},
    'Neamt': {'Iasi': 87},
    'Oradea': {'Sibiu': 151, 'Zerind': 70},
    'Pitesti': {'Bucharest': 101, 'Craiova': 138, 'Rimnicu Vilcea': 97},
    'Rimnicu Vilcea': {'Craiova': 146, 'Pitesti': 97, 'Sibiu': 80},
    'Sibiu': {'Arad': 140, 'Oradea': 151},
    'Timisoara': {'Arad': 118, 'Lugoj': 111},
    'Urziceni': {'Bucharest': 85, 'Hirsova': 98, 'Vaslui': 142},
    'Vaslui': {'Iasi': 92, 'Urziceni': 142},
    'Zerind': {'Arad': 75, 'Oradea': 71}
}


class graphProblem:

    def __init__(self, initial, goal, graph):
        self.initial = initial
        self.goal = goal
        self.graph = graph

    def actions(self, state):
        return list(self.graph[state].keys())

    def result(self, state, action):
        return action

    def goal_test(self, state):
        return state == self.goal

    def path_cost(self, cost_so_far, state1, action, state2):
        return cost_so_far + self.graph[state1][state2]


class Node:
    def __init__(self, state, parent=None, action=None, path_cost=0):
        self.state = state
        self.parent = parent
        self.action = action
        self.path_cost = path_cost

    def expand(self, graphProblem):
        return [self.child_node(graphProblem, action)
                for action in graphProblem.actions(self.state)]

    def child_node(self, graphProblem, action):
        next_state = graphProblem.result(self.state, action)
        return Node(next_state, self, action,
                    graphProblem.path_cost(self.path_cost, self.state, action, next_state))

    def path(self):
        node, path_back = self, []

        while node:
            path_back.append(node)
            node = node.parent

        return list(reversed(path_back))

    def solution(self):
        return [node.action for node in self.path()[1:]]


def graph_search(problem, pop_index):
    node = Node(problem.initial)

    if problem.goal_test(node.state): return node

    frontier = Queue(pop_index)

    explored = set()

    frontier.append(node)

    while frontier:

        frontier.printQueue()
        node = frontier.pop()

        print("Parent: ", node.state,
              "Childs: ", [child.state for child in node.expand(problem)])

        explored.add(node.state)

        for child in node.expand(problem):
            if problem.goal_test(child.state): return child
            if child.state not in explored and child not in frontier: frontier.append(child)

    return None


gp = graphProblem("Arad", "Bucharest", graph)

heuristicSLD = {
    'Arad': 366,
    'Bucharest': 0,
    'Craiova': 160,
    'Drobeta': 242,
    'Eforie': 161,
    'Fagaras': 176,
    'Giurgiu': 77,
    'Hirsova': 151,
    'Iasi': 226,
    'Lugoj': 244,
    'Mehadia': 241,
    'Neamt': 234,
    'Oradea': 380,
    'Pitesti': 100,
    'Rimnicu Vilcea': 193,
    'Sibiu': 253,
    'Timisoara': 329,
    'Urziceni': 80,
    'Vaslui': 199,
    'Zerind': 374
}


def best_first_search(problem, f, pop_index=0):
    node = Node(problem.initial)
    if problem.goal_test(node.state): return node

    frontier = Queue(pop_index)
    frontier.sortAppend(node, f)

    explored = Queue()

    while frontier:

        frontier.printQueue()
        node = frontier.pop()

        # print("Parent: ",node.state,
        #      "Childs: ",[child.state for child in node.expand(problem)])

        if problem.goal_test(node.state): return node
        explored.append(node)

        for child in node.expand(problem):
            if child not in explored and child not in frontier:
                frontier.sortAppend(child, f)

    return None


def uniform_cost_search(problem):
    return best_first_search(problem, lambda node: node.path_cost)


def GBFS(problem):
    return best_first_search(problem, lambda node: heuristicSLD[node.state])


def aStar_search(problem):
    return best_first_search(problem, lambda node: node.path_cost + heuristicSLD[node.state])


print("=======================================")
print()
print("----------GBFS State Space-------------")

goalNode = GBFS(gp)
print("Result:", goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
print("=======================================")
print()

print("----------A* State Space-------------")

goalNode = aStar_search(gp)
print("Result:", goalNode.solution())
print("Path Cost: ", goalNode.path_cost)
# Out:
# =======================================
#
# ----------GBFS State Space-------------
# Frontier Status After Adding .............
# ['Arad']
# Frontier Status After Adding .............
# ['Sibiu', 'Timisoara', 'Zerind']
# Frontier Status After Adding .............
# ['Timisoara', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Mehadia', 'Timisoara', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Drobeta', 'Lugoj', 'Timisoara', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Craiova', 'Mehadia', 'Lugoj', 'Timisoara', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Pitesti', 'Rimnicu Vilcea', 'Mehadia', 'Drobeta', 'Lugoj', 'Timisoara', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Frontier Status After Adding .............
# ['Bucharest', 'Craiova', 'Rimnicu Vilcea', 'Rimnicu Vilcea', 'Mehadia', 'Drobeta', 'Lugoj', 'Timisoara', 'Arad', 'Arad', 'Zerind', 'Oradea']
# Result: ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# Path Cost:  733
# =======================================
#
# ----------A* State Space-------------
# Frontier Status After Adding .............
# ['Arad']
# Frontier Status After Adding .............
# ['Sibiu', 'Timisoara', 'Zerind']
# Frontier Status After Adding .............
# ['Timisoara', 'Zerind', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Lugoj', 'Arad', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Arad', 'Oradea', 'Arad', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Arad', 'Oradea', 'Mehadia', 'Arad', 'Arad', 'Timisoara', 'Oradea']
# Frontier Status After Adding .............
# ['Oradea', 'Mehadia', 'Sibiu', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Timisoara', 'Oradea']
# Frontier Status After Adding .............
# ['Mehadia', 'Sibiu', 'Sibiu', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Timisoara', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Sibiu', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Timisoara', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Timisoara', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Lugoj', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Arad', 'Lugoj', 'Drobeta', 'Lugoj', 'Arad', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Drobeta', 'Lugoj', 'Sibiu', 'Arad', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Drobeta', 'Lugoj', 'Sibiu', 'Arad', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Sibiu', 'Arad', 'Craiova', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Arad', 'Craiova', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Mehadia', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Arad', 'Craiova', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Mehadia', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Craiova', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Mehadia', 'Mehadia', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Arad', 'Arad', 'Oradea', 'Timisoara', 'Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Zerind', 'Mehadia', 'Mehadia', 'Timisoara', 'Zerind', 'Pitesti', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Arad', 'Oradea', 'Timisoara', 'Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Timisoara', 'Zerind', 'Pitesti', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Oradea', 'Timisoara', 'Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Timisoara', 'Zerind', 'Pitesti', 'Timisoara', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Timisoara', 'Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Timisoara', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Oradea', 'Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Timisoara', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Oradea', 'Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Mehadia', 'Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Timisoara', 'Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Lugoj', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Mehadia', 'Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Mehadia', 'Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Lugoj', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Sibiu', 'Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Lugoj', 'Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Timisoara', 'Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Mehadia', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Mehadia', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Zerind', 'Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Oradea', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Pitesti', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Frontier Status After Adding .............
# ['Bucharest', 'Zerind', 'Timisoara', 'Zerind', 'Zerind', 'Timisoara', 'Zerind', 'Arad', 'Arad', 'Lugoj', 'Lugoj', 'Drobeta', 'Oradea', 'Mehadia', 'Lugoj', 'Lugoj', 'Drobeta', 'Drobeta', 'Mehadia', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Oradea', 'Timisoara', 'Timisoara', 'Oradea', 'Arad', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Drobeta', 'Arad', 'Arad', 'Timisoara', 'Timisoara', 'Oradea', 'Rimnicu Vilcea', 'Arad', 'Craiova', 'Arad', 'Arad', 'Arad', 'Arad', 'Oradea', 'Arad', 'Oradea', 'Oradea', 'Oradea', 'Oradea', 'Oradea']
# Result: ['Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Pitesti', 'Bucharest']
# Path Cost:  733
